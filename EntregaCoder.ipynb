# %% [markdown]
# <a href="https://colab.research.google.com/github/naorlando/promptgenrepo/blob/main/EntregaCoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.10.6)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.32.3)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
from google import genai

# %%
from google.genai import types

# %%
client = genai.Client(api_key='AIzaSyAVhPPZ0VDCH817JEdKQt4EUBjHGzgKYbA')

# %%
sys_instruct= """
ERES UN EXPERTO PROGRAMADOR DE HTML, SABES GENERAR SCRIPTS HTML CON CSS Y JS
COMPRENDES DE ANIMACIONES CON JS Y TIENES UNA MAESTRIA EN UX PARA LOS COLORES Y LA  FORMA DE DISEÑAR
"""

# %%
ruta_archivo= "/content/data.txt"

try:
  with open(ruta_archivo, 'r',encoding='utf-8') as archivo:
    texto= archivo.read()

  response = client.models.generate_content(
  model = "gemini-2.0-flash",
  config = types.GenerateContentConfig(
      system_instruction=sys_instruct,
      temperature= 0.9,

      ),
      contents=[texto]
)

  print(response.text)

except FileNotFoundError:
  print(f"Error: No se encontró el archivo en la ruta: {ruta_archivo}")

except Exception as e:
  print(f"Ocurrió un error: {e}")
# Out:
# ¡Entendido! Crear una landpage completa como la de Nike es un proyecto ambicioso que requiere una inversión significativa de tiempo y recursos. Sin embargo, puedo proporcionarte una estructura HTML básica con CSS y JavaScript para simular algunos elementos clave y darle un aspecto moderno y atractivo.
#
# **Puntos importantes a tener en cuenta:**
#
# *   **Este es un ejemplo simplificado.** No incluye todas las funcionalidades y detalles de la página real de Nike.
# *   **Las imágenes son esenciales.** Para que se parezca a la página de Nike, necesitarás obtener imágenes de alta calidad de productos, modelos, etc. Puedes usar imágenes de stock o, idealmente, tus propias imágenes.  Reemplaza los placeholders en el código con las rutas correctas.
# *   **Adaptación a dispositivos móviles.** El código incluye una estructura básica para que sea responsive, pero deberás refinarlo para que se vea perfecto en diferentes tamaños de pantalla.
# *   **Animaciones.**  He incluido algunas animaciones básicas con CSS y JavaScript. Puedes agregar más para mejorar la experiencia del usuario.
# *   **SEO.** Considera la optimización SEO (meta descripciones, títulos, etiquetas alt en las imágenes, etc.) para mejorar el posicionamiento en buscadores.
#
# Aquí tienes el código HTML, CSS y JavaScript:
#
# ```html
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Tu Landpage tipo Nike</title>
#     <link rel="stylesheet" href="style.css">
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0/css/all.min.css" integrity="sha512-9usAa10IRO0HhonpyAIVpjrylPvoDwiPUiKdWk5t3PyolY1cOd4DSE0Ga+ri4AuTroPR5aQvXU9xC6qOPnzFeg==" crossorigin="anonymous" referrerpolicy="no-referrer" />
# </head>
# <body>
#
#     <header>
#         <nav>
#             <div class="logo">
#                 <img src="img/nike-logo.svg" alt="Logo Nike">
#             </div>
#             <ul class="menu">
#                 <li><a href="#">Novedades</a></li>
#                 <li><a href="#">Hombre</a></li>
#                 <li><a href="#">Mujer</a></li>
#                 <li><a href="#">Niños</a></li>
#                 <li><a href="#">Ofertas</a></li>
#             </ul>
#             <div class="acciones">
#                 <input type="text" placeholder="Buscar">
#                 <a href="#"><i class="fas fa-shopping-bag"></i></a>
#                 <a href="#"><i class="fas fa-user"></i></a>
#             </div>
#         </nav>
#     </header>
#
#     <section class="hero">
#         <div class="hero-content">
#             <h1>Nueva Colección</h1>
#             <p>Descubre las últimas zapatillas y ropa deportiva.</p>
#             <a href="#" class="btn">Comprar Ahora</a>
#         </div>
#         <div class="hero-image">
#             <img src="img/hero-zapatilla.png" alt="Zapatilla Destacada">
#         </div>
#     </section>
#
#     <section class="featured">
#         <h2>Destacados</h2>
#         <div class="featured-grid">
#             <div class="featured-item">
#                 <img src="img/zapatilla1.png" alt="Zapatilla 1">
#                 <h3>Zapatilla X</h3>
#                 <p>Descripción breve.</p>
#                 <a href="#" class="btn">Ver más</a>
#             </div>
#             <div class="featured-item">
#                 <img src="img/zapatilla2.png" alt="Zapatilla 2">
#                 <h3>Zapatilla Y</h3>
#                 <p>Descripción breve.</p>
#                 <a href="#" class="btn">Ver más</a>
#             </div>
#             <div class="featured-item">
#                 <img src="img/zapatilla3.png" alt="Zapatilla 3">
#                 <h3>Zapatilla Z</h3>
#                 <p>Descripción breve.</p>
#                 <a href="#" class="btn">Ver más</a>
#             </div>
#         </div>
#     </section>
#
#     <footer>
#         <p>© 2024 Tu Marca. Todos los derechos reservados.</p>
#     </footer>
#
#     <script src="script.js"></script>
# </body>
# </html>
# ```
#
# ```css
# /* style.css */
#
# /* General */
# body {
#     font-family: 'Arial', sans-serif;
#     margin: 0;
#     padding: 0;
#     background-color: #f4f4f4;
#     color: #333;
#     line-height: 1.6;
# }
#
# a {
#     color: #007bff;
#     text-decoration: none;
# }
#
# a:hover {
#     text-decoration: underline;
# }
#
# .btn {
#     background-color: #000;
#     color: #fff;
#     padding: 10px 20px;
#     border-radius: 5px;
#     display: inline-block;
#     margin-top: 20px;
# }
#
# .btn:hover {
#     background-color: #333;
#     text-decoration: none;
# }
#
# /* Header */
# header {
#     background-color: #fff;
#     padding: 10px 0;
#     box-shadow: 0 2px 5px rgba(0, 0, 0, 0.1);
#     position: sticky;
#     top: 0;
#     z-index: 100;
# }
#
# nav {
#     display: flex;
#     justify-content: space-around;
#     align-items: center;
#     max-width: 1200px;
#     margin: 0 auto;
#     padding: 0 20px;
# }
#
# .logo img {
#     width: 80px;
# }
#
# .menu {
#     list-style: none;
#     display: flex;
# }
#
# .menu li {
#     margin-left: 20px;
# }
#
# .menu li a {
#     color: #333;
#     font-weight: bold;
# }
#
# .acciones input[type="text"] {
#     padding: 8px;
#     border: 1px solid #ccc;
#     border-radius: 4px;
# }
#
# .acciones a {
#     margin-left: 15px;
#     color: #555;
#     font-size: 1.2em;
# }
#
# /* Hero Section */
# .hero {
#     background-image: url('img/fondo-hero.jpg'); /* Reemplaza con tu imagen */
#     background-size: cover;
#     background-position: center;
#     color: #fff;
#     text-align: center;
#     padding: 100px 0;
# }
#
# .hero-content {
#     max-width: 800px;
#     margin: 0 auto;
# }
#
# .hero-content h1 {
#     font-size: 3em;
#     margin-bottom: 20px;
# }
#
# .hero-image img {
#     width: 400px;
#     margin-top: 30px;
#     animation: floatImage 4s ease-in-out infinite;
# }
#
# @keyframes floatImage {
#     0%, 100% {
#         transform: translateY(0);
#     }
#     50% {
#         transform: translateY(-20px);
#     }
# }
#
# /* Featured Section */
# .featured {
#     padding: 50px 0;
#     text-align: center;
# }
#
# .featured h2 {
#     font-size: 2.5em;
#     margin-bottom: 30px;
# }
#
# .featured-grid {
#     display: grid;
#     grid-template-columns: repeat(auto-fit, minmax(300px, 1fr));
#     gap: 30px;
#     max-width: 1200px;
#     margin: 0 auto;
#     padding: 0 20px;
# }
#
# .featured-item {
#     background-color: #fff;
#     padding: 20px;
#     border-radius: 8px;
#     box-shadow: 0 2px 5px rgba(0, 0, 0, 0.1);
# }
#
# .featured-item img {
#     width: 100%;
#     border-radius: 8px;
#     margin-bottom: 15px;
# }
#
# .featured-item h3 {
#     font-size: 1.5em;
#     margin-bottom: 10px;
# }
#
# /* Footer */
# footer {
#     background-color: #333;
#     color: #fff;
#     text-align: center;
#     padding: 20px 0;
# }
#
# /* Responsive Design */
# @media (max-width: 768px) {
#     nav {
#         flex-direction: column;
#         align-items: flex-start;
#     }
#
#     .logo {
#         margin-bottom: 10px;
#     }
#
#     .menu {
#         flex-direction: column;
#         margin-bottom: 10px;
#     }
#
#     .menu li {
#         margin-left: 0;
#         margin-bottom: 5px;
#     }
#
#     .acciones {
#         align-self: stretch;
#         width: 100%;
#         text-align: center;
#     }
#
#     .acciones input[type="text"] {
#         width: 70%;
#         margin-bottom: 10px;
#     }
#
#     .hero {
#         padding: 50px 0;
#     }
#
#     .hero-content h1 {
#         font-size: 2.5em;
#     }
#
#     .hero-image img {
#         width: 80%;
#     }
# }
# ```
#
# ```javascript
# // script.js
#
# document.addEventListener('DOMContentLoaded', () => {
#     // Ejemplo de animación (puedes agregar más)
#     const heroImage = document.querySelector('.hero-image img');
#
#     heroImage.addEventListener('mouseover', () => {
#         heroImage.style.transform = 'scale(1.1)';
#         heroImage.style.transition = 'transform 0.3s ease';
#     });
#
#     heroImage.addEventListener('mouseout', () => {
#         heroImage.style.transform = 'scale(1)';
#     });
#
#     // Puedes agregar más interacciones y animaciones aquí
# });
# ```
#
# **Explicación del código:**
#
# *   **HTML:** Estructura básica con un header, sección hero, sección de productos destacados y footer.
# *   **CSS:**  Estilos para la apariencia, incluyendo un diseño responsive básico.  Utiliza un esquema de colores similar al de Nike (blanco, negro, gris y un azul/cian como acento).  Define una tipografía moderna y legible.  Incluye animaciones sutiles para mejorar la experiencia visual.
# *   **JavaScript:**  Un ejemplo básico de animación para la imagen del hero.  Puedes expandir esto para agregar más interacciones y efectos.
#
# **Pasos para usar el código:**
#
# 1.  Crea un archivo `index.html` y copia el código HTML.
# 2.  Crea un archivo `style.css` y copia el código CSS.
# 3.  Crea un archivo `script.js` y copia el código JavaScript.
# 4.  Crea una carpeta `img` y coloca las imágenes que vas a usar (reemplaza los placeholders en el HTML).
# 5.  Abre el archivo `index.html` en tu navegador.
#
# **Cómo mejorar aún más la landpage:**
#
# *   **Animaciones avanzadas:** Usa librerías como GSAP para crear animaciones más complejas y fluidas.
# *   **Efectos de scroll:** Implementa efectos parallax o animaciones que se activen al hacer scroll.
# *   **Formulario de contacto:** Agrega un formulario para que los usuarios puedan contactarte.
# *   **Integración con redes sociales:** Incluye enlaces a tus perfiles en redes sociales.
# *   **Pruebas A/B:** Realiza pruebas A/B para optimizar el diseño y el contenido de la landpage.
# *   **Optimización de imágenes:** Utiliza herramientas para optimizar las imágenes para la web (reducir el tamaño sin perder calidad).
#
# ¡Espero que esto te ayude a empezar!  Si tienes alguna pregunta o necesitas ayuda con algún aspecto específico, no dudes en preguntar.
